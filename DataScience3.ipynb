# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Part-1**
#
# ---

# %%
file = pd.read_csv('exp.csv')
file
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
file.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
file.shape
# Out:
# (50, 7)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
file.dtypes
# Out:
# Mthly_HH_Income              int64
# Mthly_HH_Expense             int64
# No_of_Fly_Members            int64
# Emi_or_Rent_Amt              int64
# Annual_HH_Income             int64
# Highest_Qualified_Member    object
# No_of_Earning_Members        int64
# dtype: object

# %%
file.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
file.describe(include='all')
# Out:
#         Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count         50.000000         50.000000          50.000000        50.000000
# unique              NaN               NaN                NaN              NaN
# top                 NaN               NaN                NaN              NaN
# freq                NaN               NaN                NaN              NaN
# mean       41558.000000      18818.000000           4.060000      3060.000000
# std        26097.908979      12090.216824           1.517382      6241.434948
# min         5000.000000       2000.000000           1.000000         0.000000
# 25%        23550.000000      10000.000000           3.000000         0.000000
# 50%        35000.000000      15500.000000           4.000000         0.000000
# 75%        50375.000000      25000.000000           5.000000      3500.000000
# max       100000.000000      50000.000000           7.000000     35000.000000
#
# ...

# %%
file.describe(include=['object'])
# Out:
#        Highest_Qualified_Member
# count                        50
# unique                        5
# top                    Graduate
# freq                         19

# %%
file.describe(include=['int64'])
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %% [markdown]
# **Mean**

# %%
mean_monthly = file['Mthly_HH_Income'].mean()
print("Mean of monthly income:-",mean_monthly)
# Out:
# Mean of monthly income:- 41558.0

# %%
mean_monthly_exp = file['Mthly_HH_Expense'].mean()
print("Mean of monthly expense:-",mean_monthly_exp)
# Out:
# Mean of monthly expense:- 18818.0

# %%
mean_annual = file['Annual_HH_Income'].mean()
print("Mean of annual income:-",mean_annual)
# Out:
# Mean of annual income:- 490019.04

# %%
mean_emi = file['Emi_or_Rent_Amt'].mean()
print("Mean of EMI or Rent:-",mean_emi)
# Out:
# Mean of EMI or Rent:- 3060.0

# %% [markdown]
# **Median**

# %%
median_monthly = file['Mthly_HH_Income'].median()
print("Median of monthly income:-",median_monthly)
median_monthly_exp = file['Mthly_HH_Expense'].median()
print("Median of monthly expense:-",median_monthly_exp)
median_annual = file['Annual_HH_Income'].median()
print("Median of annual income:-",median_annual)
median_emi = file['Emi_or_Rent_Amt'].median()
print("Median of EMI or Rent:-",median_emi)
# Out:
# Median of monthly income:- 35000.0
# Median of monthly expense:- 15500.0
# Median of annual income:- 447420.0
# Median of EMI or Rent:- 0.0

# %% [markdown]
# **Mode**

# %%
mode_monthly = file['Mthly_HH_Income'].mode()
print("Mode of monthly income:-",mode_monthly)
mode_monthly_exp = file['Mthly_HH_Expense'].mode()
print("Mode of monthly expense:-",mode_monthly_exp)
mode_annual = file['Annual_HH_Income'].mode()
print("Mode of annual income:-",mode_annual)
mode_emi = file['Emi_or_Rent_Amt'].mode()
print("Mode of EMI or Rent:-",mode_emi)
# Out:
# Mode of monthly income:- 0    45000
# Name: Mthly_HH_Income, dtype: int64
# Mode of monthly expense:- 0    25000
# Name: Mthly_HH_Expense, dtype: int64
# Mode of annual income:- 0    590400
# Name: Annual_HH_Income, dtype: int64
# Mode of EMI or Rent:- 0    0
# Name: Emi_or_Rent_Amt, dtype: int64

# %%
data = file['Mthly_HH_Income']
sns.distplot(data, bins=10, hist=True, kde=True,
             label = 'Monthly Revenue (in millions)')
# Out:
# <Axes: xlabel='Mthly_HH_Income', ylabel='Density'>

# %%
data = file['Mthly_HH_Expense']
sns.distplot(data, bins=10, hist=True, kde=True,
             label = 'Monthly Expense (in millions)')
# Out:
# <Axes: xlabel='Mthly_HH_Expense', ylabel='Density'>

# %%
data = file['Annual_HH_Income']
sns.distplot(data, bins=10, hist=True, kde=True,
             label = 'Annual Revenue (in millions)')
# Out:
# <Axes: xlabel='Annual_HH_Income', ylabel='Density'>

# %%
data = file['Emi_or_Rent_Amt']
sns.distplot(data, bins=10, hist=True, kde=True,
             label = 'EMI or Rent Amount (in millions)')
# Out:
# <Axes: xlabel='Emi_or_Rent_Amt', ylabel='Density'>

# %% [markdown]
# **Minimum Monthly and Annual Income**

# %%
print("Minimum monthly income:-",file['Mthly_HH_Income'].min())
print("Minimum annual income:-",file['Annual_HH_Income'].min())
# Out:
# Minimum monthly income:- 5000
# Minimum annual income:- 64200

# %% [markdown]
# **Maximum Monthly and Annual Income**

# %%
print("Maximum monthly income:-",file['Mthly_HH_Income'].max())
print("Maximum annual income:-",file['Annual_HH_Income'].max())
# Out:
# Maximum monthly income:- 100000
# Maximum annual income:- 1404000

# %% [markdown]
# **Range of Monthly and Annual Income**

# %%
print("Range of Monthly Income:- ",file['Mthly_HH_Income'].max() -
      file['Mthly_HH_Income'].min())
print("Range of Annual Income:- ",file['Annual_HH_Income'].max() -
      file['Annual_HH_Income'].min())
# Out:
# Range of Monthly Income:-  95000
# Range of Annual Income:-  1339800

# %% [markdown]
# **Variance**

# %%
print("Variance of monthly income:-",file['Mthly_HH_Income'].var())
print("Variance of monthly expense:-",file['Mthly_HH_Expense'].var())
print("Variance of annual income:-",file['Annual_HH_Income'].var())
print("Variance of EMI or Rent:-",file['Emi_or_Rent_Amt'].var())
# Out:
# Variance of monthly income:- 681100853.0612245
# Variance of monthly expense:- 146173342.85714287
# Variance of annual income:- 102486925397.91673
# Variance of EMI or Rent:- 38955510.20408163

# %% [markdown]
# **Standard Deviation**

# %%
print("Standard Deviation of monthly income:-",file['Mthly_HH_Income'].std())
print("Standard Deviation of monthly expense:-",file['Mthly_HH_Expense'].std())
print("Standard Deviation of annual income:-",file['Annual_HH_Income'].std())
print("Standard Deviation of EMI or Rent:-",file['Emi_or_Rent_Amt'].std())
# Out:
# Standard Deviation of monthly income:- 26097.908978713687
# Standard Deviation of monthly expense:- 12090.216824240286
# Standard Deviation of annual income:- 320135.7921225253
# Standard Deviation of EMI or Rent:- 6241.434947516607

# %% [markdown]
# **1st Quartile Deviation**

# %%
print("1st Quartile Deviation of monthly income:-",
      file['Mthly_HH_Income'].quantile(0.25))
print("1st Quartile Deviation of monthly expense:-",
      file['Mthly_HH_Expense'].quantile(0.25))
print("1st Quartile Deviation of annual income:-",
      file['Annual_HH_Income'].quantile(0.25))
print("1st Quartile Deviation of EMI or Rent:-",
      file['Emi_or_Rent_Amt'].quantile(0.25))
# Out:
# 1st Quartile Deviation of monthly income:- 23550.0
# 1st Quartile Deviation of monthly expense:- 10000.0
# 1st Quartile Deviation of annual income:- 258750.0
# 1st Quartile Deviation of EMI or Rent:- 0.0

# %% [markdown]
# **2nd Quartile Deviation**

# %%
print("2nd Quartile Deviation of monthly income:-",
      file['Mthly_HH_Income'].quantile(0.5))
print("2nd Quartile Deviation of monthly expense:-",
      file['Mthly_HH_Expense'].quantile(0.5))
print("2nd Quartile Deviation of annual income:-",
      file['Annual_HH_Income'].quantile(0.5))
print("2nd Quartile Deviation of EMI or Rent:-",
      file['Emi_or_Rent_Amt'].quantile(0.5))
# Out:
# 2nd Quartile Deviation of monthly income:- 35000.0
# 2nd Quartile Deviation of monthly expense:- 15500.0
# 2nd Quartile Deviation of annual income:- 447420.0
# 2nd Quartile Deviation of EMI or Rent:- 0.0

# %% [markdown]
# **3rd Quartile Deviation**

# %%
print("3rd Quartile Deviation of monthly income:-",
      file['Mthly_HH_Income'].quantile(0.75))
print("3rd Quartile Deviation of monthly expense:-",
      file['Mthly_HH_Expense'].quantile(0.75))
print("3rd Quartile Deviation of annual income:-",
      file['Annual_HH_Income'].quantile(0.75))
print("3rd Quartile Deviation of EMI or Rent:-",
      file['Emi_or_Rent_Amt'].quantile(0.75))
# Out:
# 3rd Quartile Deviation of monthly income:- 50375.0
# 3rd Quartile Deviation of monthly expense:- 25000.0
# 3rd Quartile Deviation of annual income:- 594720.0
# 3rd Quartile Deviation of EMI or Rent:- 3500.0

# %% [markdown]
# **Skewness**

# %%
print("Skewness of monthly income:", skew(file['Mthly_HH_Income']))
print("Skewness of monthly expense:", skew(file['Mthly_HH_Expense']))
print("Skewness of annual income:", skew(file['Annual_HH_Income']))
print("Skewness of EMI or Rent:", skew(file['Emi_or_Rent_Amt']))
# Out:
# Skewness of monthly income: 0.8966419872996332
# Skewness of monthly expense: 1.1631728469608633
# Skewness of annual income: 1.156858143785799
# Skewness of EMI or Rent: 3.3007064211477792

# %% [markdown]
# **Kurtosis**

# %%
print("Kurtosis of monthly income:", kurtosis(file['Mthly_HH_Income']))
print("Kurtosis of monthly expense:", kurtosis(file['Mthly_HH_Expense']))
print("Kurtosis of annual income:", kurtosis(file['Annual_HH_Income']))
print("Kurtosis of EMI or Rent:", kurtosis(file['Emi_or_Rent_Amt']))
# Out:
# Kurtosis of monthly income: -0.013332948688498103
# Kurtosis of monthly expense: 0.7331960636897663
# Kurtosis of annual income: 0.87655548957901
# Kurtosis of EMI or Rent: 12.703838128758802

# %% [markdown]
# **Summary statistics of Monthly income grouped by the Highest Qualification**

# %%
summary_stats = file.groupby('Highest_Qualified_Member')['Mthly_HH_Income'].describe()
summary_stats
# Out:
#                           count          mean           std      min      25%  \
# Highest_Qualified_Member
# Graduate                   19.0  40921.052632  23460.524266  12500.0  24500.0
# Illiterate                  5.0  25280.000000  23436.979328   6000.0  10000.0
# Post-Graduate               6.0  59166.666667  31530.408603  15000.0  45000.0
# Professional               10.0  52550.000000  25460.699563  32000.0  34250.0
# Under-Graduate             10.0  29350.000000  22541.381699   5000.0  19250.0
#
#                               50%      75%       max
# Highest_Qualified_Member
# Graduate                  35000.0  50500.0  100000.0
# Illiterate                22000.0  23400.0   65000.0
# Post-Graduate             52500.0  82500.0  100000.0
# Professional              46000.0  50375.0  100000.0
# Under-Graduate            22500.0  36875.0   85000.0

# %% [markdown]
# **Summary statistics of Monthly income grouped by the Number of Earning Members**

# %%
summary_stats1 = file.groupby('No_of_Earning_Members')['Mthly_HH_Income'].describe()
summary_stats1
# Out:
#                        count          mean           std      min      25%  \
# No_of_Earning_Members
# 1                       33.0  34830.303030  21580.597258   5000.0  19000.0
# 2                       12.0  51791.666667  29607.629801  20000.0  24000.0
# 3                        4.0  65000.000000  35823.642100  25000.0  40000.0
# 4                        1.0  47000.000000           NaN  47000.0  47000.0
#
#                            50%      75%       max
# No_of_Earning_Members
# 1                      32000.0  45000.0  100000.0
# 2                      47750.0  70000.0  100000.0
# 3                      67500.0  92500.0  100000.0
# 4                      47000.0  47000.0   47000.0

# %% [markdown]
# **Summary statistics of Annual income grouped by the Highest Qualification**

# %%
summary_stats2 = file.groupby('Highest_Qualified_Member')['Annual_HH_Income'].describe()
summary_stats2
# Out:
#                           count           mean            std       min  \
# Highest_Qualified_Member
# Graduate                   19.0  499042.105263  317203.071997  147000.0
# Illiterate                  5.0  279278.400000  228348.854547   79920.0
# Post-Graduate               6.0  668500.000000  396381.528328  167400.0
# Professional               10.0  599520.000000  270481.035195  330480.0
# Under-Graduate             10.0  361656.000000  308890.819805   64200.0
#
#                                25%       50%       75%        max
# Highest_Qualified_Member
# Graduate                  253500.0  466200.0  598380.0  1404000.0
# Illiterate                 97200.0  279840.0  292032.0   647400.0
# Post-Graduate             475650.0  600300.0  816750.0  1320000.0
# Professional              451260.0  488400.0  578820.0  1152480.0
# Under-Graduate            219360.0  268200.0  397440.0  1142400.0

# %% [markdown]
# **Summary statistics of Annual income grouped by the Number of Earning Members**

# %%
summary_stats3 = file.groupby('No_of_Earning_Members')['Annual_HH_Income'].describe()
summary_stats3
# Out:
#                        count           mean            std       min  \
# No_of_Earning_Members
# 1                       33.0  418129.454545  273314.234444   64200.0
# 2                       12.0  597870.000000  340238.938128  220800.0
# 3                        4.0  767850.000000  496003.800389  258000.0
# 4                        1.0  456840.000000            NaN  456840.0
#
#                             25%       50%        75%        max
# No_of_Earning_Members
# 1                      218880.0  385200.0   570000.0  1320000.0
# 2                      307200.0  544680.0   743550.0  1152480.0
# 3                      457350.0  704700.0  1015200.0  1404000.0
# 4                      456840.0  456840.0   456840.0   456840.0

# %% [markdown]
# **Summary statistics of Monthly expense grouped by the Highest Qualification**

# %%
summary_stats4 = file.groupby('Highest_Qualified_Member')['Mthly_HH_Expense'].describe()
summary_stats4
# Out:
#                           count          mean           std      min      25%  \
# Highest_Qualified_Member
# Graduate                   19.0  18705.263158  12026.012255   6600.0  11250.0
# Illiterate                  5.0  11800.000000  10084.641788   2000.0   5000.0
# Post-Graduate               6.0  24333.333333  16070.677231  10000.0  11500.0
# Professional               10.0  25400.000000  11226.951699  15000.0  19250.0
# Under-Graduate             10.0  12650.000000   7333.522725   4500.0   8250.0
#
#                               50%      75%      max
# Highest_Qualified_Member
# Graduate                  13000.0  22500.0  50000.0
# Illiterate                 7000.0  20000.0  25000.0
# Post-Graduate             19000.0  35500.0  48000.0
# Professional              22500.0  25000.0  50000.0
# Under-Graduate             9500.0  16000.0  25000.0

# %% [markdown]
# **Summary statistics of Monthly income grouped by the Number of Earning Members**

# %%
summary_stats1 = file.groupby('No_of_Earning_Members')['Mthly_HH_Expense'].describe()
summary_stats1
# Out:
#                        count          mean           std      min      25%  \
# No_of_Earning_Members
# 1                       33.0  15618.181818  10077.030023   2000.0   9000.0
# 2                       12.0  24791.666667  13617.265667   9000.0  16125.0
# 3                        4.0  28250.000000  15671.098664  10000.0  21250.0
# 4                        1.0  15000.000000           NaN  15000.0  15000.0
#
#                            50%      75%      max
# No_of_Earning_Members
# 1                      12300.0  20000.0  50000.0
# 2                      22500.0  28750.0  50000.0
# 3                      27500.0  34500.0  48000.0
# 4                      15000.0  15000.0  15000.0

# %% [markdown]
# # **Part-2**
#
#
# ---

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
setosa = df['Species'] == 'Iris-setosa'
print("Statistical details for 'Iris-setosa':")
df[setosa].describe()
# Out:
# Statistical details for 'Iris-setosa':
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
versicolor = df['Species'] == 'Iris-versicolor'
print("Statistical details for 'Iris-versicolor':")
df[versicolor].describe()
# Out:
# Statistical details for 'Iris-versicolor':
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
virginica = df['Species'] == 'Iris-virginica'
print("Statistical details for 'Iris-virginica':")
df[virginica].describe()
# Out:
# Statistical details for 'Iris-virginica':
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %% [markdown]
# **Iris-setosa**

# %%
print(df[setosa].describe())
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
df['SepalLengthCm'].min()
# Out:
# 4.3

# %%
df['SepalLengthCm'].max()
# Out:
# 7.9

# %%
df['SepalLengthCm'].std()
# Out:
# 0.828066127977863

# %%
df['SepalLengthCm'].var()
# Out:
# 0.6856935123042507

# %%
df['SepalLengthCm'].max() - df['SepalLengthCm'].min()
# Out:
# 3.6000000000000005

# %% [markdown]
# **Iris-versicolor**

# %%
print(df[versicolor].describe())
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
df['SepalWidthCm'].max()
# Out:
# 4.4

# %%
df['SepalWidthCm'].min()
# Out:
# 2.0

# %%
df['SepalWidthCm'].max() - df['SepalWidthCm'].min()
# Out:
# 2.4000000000000004

# %%
df['SepalWidthCm'].var()
# Out:
# 0.1880040268456376

# %%
df['SepalWidthCm'].std()
# Out:
# 0.4335943113621737

# %% [markdown]
# **Iris-virginica**

# %%
print(df[virginica].describe())
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %%
df['PetalLengthCm'].max()
# Out:
# 6.9

# %%
df['PetalLengthCm'].min()
# Out:
# 1.0

# %%
df['PetalLengthCm'].max() - df['PetalLengthCm'].min()
# Out:
# 5.9

# %%
df['PetalLengthCm'].var()
# Out:
# 3.113179418344519

# %%
df['PetalLengthCm'].std()
# Out:
# 1.7644204199522626

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x='Species', y='SepalWidthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.boxplot(x='Species', y='PetalLengthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x='Species', y='PetalWidthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>
