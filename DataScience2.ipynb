# %%
import numpy as np
import pandas as pd

# %%
file = pd.read_csv('academic.csv',na_values='?')
file
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1        M          KW       KuwaIT    lowerlevel    G-04         A      NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         C      NaN
# 3        M          KW       KuwaIT    lowerlevel     NaN         A       IT
# 4        M          KW       KuwaIT    lowerlevel     NaN         A       IT
# ..     ...         ...          ...           ...     ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A      NaN
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A      NaN
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A      NaN
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A      NaN
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A  History
#
# ...

# %%
file.isnull()
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0     False        False         False    False    False      False  False
# 1     False        False         False    False    False      False   True
# 2     False        False         False    False    False      False   True
# 3     False        False         False    False     True      False  False
# 4     False        False         False    False     True      False  False
# ..      ...          ...           ...      ...      ...        ...    ...
# 475   False        False         False    False    False      False   True
# 476   False        False         False    False    False      False   True
# 477   False        False         False    False    False      False   True
# 478   False        False         False    False    False      False   True
# 479   False        False         False    False    False      False  False
#
# ...

# %%
file.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                     14
# SectionID                    0
# Topic                       22
# Semester                     0
# Relation                    10
# raisedhands                  9
# VisITedResources             0
# AnnouncementsView            0
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
file['Topic'] =  file['Topic'].fillna('0')
file
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A       IT
# 1        M          KW       KuwaIT    lowerlevel    G-04         A        0
# 2        M          KW       KuwaIT    lowerlevel    G-04         C        0
# 3        M          KW       KuwaIT    lowerlevel     NaN         A       IT
# 4        M          KW       KuwaIT    lowerlevel     NaN         A       IT
# ..     ...         ...          ...           ...     ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A  History
#
# ...

# %%
file.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                     14
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                    10
# raisedhands                  9
# VisITedResources             0
# AnnouncementsView            0
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
file['Relation'].dropna(axis=0, inplace=False)
# Out:
# 1      Father
# 2      Father
# 3      Father
# 7      Father
# 8      Father
#         ...
# 475    Father
# 476    Father
# 477    Father
# 478    Father
# 479    Father
# Name: Relation, Length: 470, dtype: object

# %%
file.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                     14
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                    10
# raisedhands                  9
# VisITedResources             0
# AnnouncementsView            0
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
file = file.dropna(subset=['Relation', 'GradeID'])
file
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 1        M          KW       KuwaIT    lowerlevel    G-04         A        0
# 2        M          KW       KuwaIT    lowerlevel    G-04         C        0
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A        0
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A        0
# ..     ...         ...          ...           ...     ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A  History
#
# ...

# %%
file.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 8
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
file['raisedhands'].replace(np.NaN,file['raisedhands'].mean(),inplace=True)
file
# Out:
# <ipython-input-11-f9125953cb6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['raisedhands'].replace(np.NaN,file['raisedhands'].mean(),inplace=True)
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 1        M          KW       KuwaIT    lowerlevel    G-04         A        0
# 2        M          KW       KuwaIT    lowerlevel    G-04         C        0
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A        0
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A        0
# ..     ...         ...          ...           ...     ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# ...

# %%
file.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
file.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   458.000000        458.000000         458.000000  458.000000
# mean     47.446667         55.430131          38.500000   42.868996
# std      30.741714         33.140978          26.778551   27.584053
# min       0.000000          0.000000           0.000000    1.000000
# 25%      17.000000         20.000000          15.000000   20.000000
# 50%      50.000000         69.000000          33.000000   39.000000
# 75%      75.000000         85.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %% [markdown]
# # **Outliers**
#
#
# ---

# %%
import matplotlib.pyplot as plt

# %%
file['Semester'].value_counts()
# Out:
# F    226
# S    224
# T      8
# Name: Semester, dtype: int64

# %%
fig,x = plt.subplots(figsize=(6,4))
ax = plt.hist(file['Semester'],color='b',edgecolor='b')
plt.title('BAR PLOT')
plt.show()

# %%
file[file['Semester'].str.contains('T')==False]
file
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 1        M          KW       KuwaIT    lowerlevel    G-04         A        0
# 2        M          KW       KuwaIT    lowerlevel    G-04         C        0
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A        0
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A        0
# ..     ...         ...          ...           ...     ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A  History
#
# ...

# %%
file['ParentAnsweringSurvey'].value_counts()
# Out:
# Yes    257
# No     201
# Name: ParentAnsweringSurvey, dtype: int64

# %%
file.drop(['ParentAnsweringSurvey'], axis=1,inplace=True)
file
# Out:
# <ipython-input-19-1c0be0e65e2a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file.drop(['ParentAnsweringSurvey'], axis=1,inplace=True)
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 1        M          KW       KuwaIT    lowerlevel    G-04         A        0
# 2        M          KW       KuwaIT    lowerlevel    G-04         C        0
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A        0
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A     Math
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A        0
# ..     ...         ...          ...           ...     ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A        0
# ...

# %% [markdown]
# # **Normalisation**
#
#
# ---

# %%
file['raisedhands'] = file['raisedhands'] / file['raisedhands'].max()
file['VisITedResources']= file['VisITedResources'] / file['VisITedResources'].max()
# Out:
# <ipython-input-20-0a7c8ec8d089>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['raisedhands'] = file['raisedhands'] / file['raisedhands'].max()
# <ipython-input-20-0a7c8ec8d089>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['VisITedResources']= file['VisITedResources'] / file['VisITedResources'].max()

# %%
file['raisedhands']
# Out:
# 1      0.200000
# 2      0.100000
# 7      0.500000
# 8      0.120000
# 10     0.474467
#          ...
# 475    0.050000
# 476    0.500000
# 477    0.550000
# 478    0.300000
# 479    0.350000
# Name: raisedhands, Length: 458, dtype: float64

# %%
file['VisITedResources']
# Out:
# 1      0.202020
# 2      0.070707
# 7      0.101010
# 8      0.212121
# 10     0.888889
#          ...
# 475    0.040404
# 476    0.777778
# 477    0.747475
# 478    0.171717
# 479    0.141414
# Name: VisITedResources, Length: 458, dtype: float64

# %%
file[['raisedhands','VisITedResources']].head(10)
# Out:
#     raisedhands  VisITedResources
# 1      0.200000          0.202020
# 2      0.100000          0.070707
# 7      0.500000          0.101010
# 8      0.120000          0.212121
# 10     0.474467          0.888889
# 11     0.474467          0.060606
# 12     0.050000          0.010101
# 13     0.200000          0.141414
# 16     0.360000          0.303030
# 17     0.550000          0.131313

# %% [markdown]
# # **Data Transformation**
#
# ---

# %%
file['GradeID'].value_counts()
# Out:
# G-02    147
# G-08    108
# G-07     96
# G-04     44
# G-06     31
# G-11     13
# G-12      7
# G-09      5
# G-10      4
# G-05      3
# Name: GradeID, dtype: int64

# %%
file.GradeID.replace({"G-02":1, "G-04":2, "G-05":3,"G-06":4,"G-07":5,"G-08":6,"G-09":7,"G-10":8,"G-11":9,"G-12":10},inplace=True)
file['GradeID'].value_counts()
# Out:
# <ipython-input-25-3a0c7eb82caf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file.GradeID.replace({"G-02":1, "G-04":2, "G-05":3,"G-06":4,"G-07":5,"G-08":6,"G-09":7,"G-10":8,"G-11":9,"G-12":10},inplace=True)
# 1     147
# 6     108
# 5      96
# 2      44
# 4      31
# 9      13
# 10      7
# 7       5
# 8       4
# 3       3
# Name: GradeID, dtype: int64

# %%
file['GradeID']
# Out:
# 1      2
# 2      2
# 7      5
# 8      5
# 10     5
#       ..
# 475    6
# 476    6
# 477    6
# 478    6
# 479    6
# Name: GradeID, Length: 458, dtype: int64

# %%
file['StudentAbsenceDays'].value_counts()
# Out:
# Under-7    279
# Above-7    179
# Name: StudentAbsenceDays, dtype: int64

# %%
file.StudentAbsenceDays.replace({"Under-7":0,"Above-7":1},inplace=True)
file['StudentAbsenceDays'].value_counts()
# Out:
# <ipython-input-28-bf13347d24eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file.StudentAbsenceDays.replace({"Under-7":0,"Above-7":1},inplace=True)
# 0    279
# 1    179
# Name: StudentAbsenceDays, dtype: int64

# %%
file['StudentAbsenceDays']
# Out:
# 1      0
# 2      1
# 7      0
# 8      0
# 10     0
#       ..
# 475    1
# 476    0
# 477    0
# 478    1
# 479    1
# Name: StudentAbsenceDays, Length: 458, dtype: int64

# %% [markdown]
# # **Binning**
#
# ---

# %%
file
# Out:
#     gender NationalITy PlaceofBirth       StageID  GradeID SectionID    Topic  \
# 1        M          KW       KuwaIT    lowerlevel        2         A        0
# 2        M          KW       KuwaIT    lowerlevel        2         C        0
# 7        M          KW       KuwaIT  MiddleSchool        5         A        0
# 8        F          KW       KuwaIT  MiddleSchool        5         A     Math
# 10       M          KW       KuwaIT  MiddleSchool        5         A        0
# ..     ...         ...          ...           ...      ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool        6         A        0
# 476      F      Jordan       Jordan  MiddleSchool        6         A        0
# 477      F      Jordan       Jordan  MiddleSchool        6         A        0
# 478      F      Jordan       Jordan  MiddleSchool        6         A        0
# 479      F      Jordan       Jordan  MiddleSchool        6         A  History
#
# ...

# %%
file['Discussion'].value_counts()
# Out:
# 40    23
# 70    21
# 33    21
# 50    17
# 30    16
#       ..
# 45     1
# 32     1
# 59     1
# 57     1
# 62     1
# Name: Discussion, Length: 89, dtype: int64

# %%
min_val = file['Discussion'].min()
max_val = file['Discussion'].max()
print(min_val)
print(max_val)
# Out:
# 1
# 99

# %%
bins = np.linspace(min_val,max_val,4)
bins
# Out:
# array([ 1.        , 33.66666667, 66.33333333, 99.        ])

# %%
labels=['small','medium','big']

# %%
file['bins']=pd.cut(file['Discussion'],bins=bins,labels=labels,include_lowest=True)
# Out:
# <ipython-input-35-004a89b7c76f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['bins']=pd.cut(file['Discussion'],bins=bins,labels=labels,include_lowest=True)

# %%
file['bins'].value_counts()
# Out:
# small     214
# medium    123
# big       121
# Name: bins, dtype: int64

# %%
file.head()
# Out:
#    gender NationalITy PlaceofBirth       StageID  GradeID SectionID Topic  \
# 1       M          KW       KuwaIT    lowerlevel        2         A     0
# 2       M          KW       KuwaIT    lowerlevel        2         C     0
# 7       M          KW       KuwaIT  MiddleSchool        5         A     0
# 8       F          KW       KuwaIT  MiddleSchool        5         A  Math
# 10      M          KW       KuwaIT  MiddleSchool        5         A     0
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 1         F   Father     0.200000          0.202020                  3
# 2         F   Father     0.100000          0.070707                  0
# 7         T   Father     0.500000          0.101010                 15
# 8         T   Father     0.120000          0.212121                 16
# 10        F   Father     0.474467          0.888889                 30
#
#     Discussion ParentschoolSatisfaction  StudentAbsenceDays Class    bins
# ...

# %%
file.describe()
# Out:
#           GradeID  raisedhands  VisITedResources  AnnouncementsView  \
# count  458.000000   458.000000        458.000000         458.000000
# mean     3.820961     0.474467          0.559900          38.500000
# std      2.431251     0.307417          0.334757          26.778551
# min      1.000000     0.000000          0.000000           0.000000
# 25%      1.000000     0.170000          0.202020          15.000000
# 50%      5.000000     0.500000          0.696970          33.000000
# 75%      6.000000     0.750000          0.858586          58.000000
# max     10.000000     1.000000          1.000000          98.000000
#
#        Discussion  StudentAbsenceDays
# count  458.000000           458.00000
# mean    42.868996             0.39083
# std     27.584053             0.48847
# min      1.000000             0.00000
# 25%     20.000000             0.00000
# 50%     39.000000             0.00000
# 75%     70.000000             1.00000
# max     99.000000             1.00000

# %%
file
# Out:
#     gender NationalITy PlaceofBirth       StageID  GradeID SectionID    Topic  \
# 1        M          KW       KuwaIT    lowerlevel        2         A        0
# 2        M          KW       KuwaIT    lowerlevel        2         C        0
# 7        M          KW       KuwaIT  MiddleSchool        5         A        0
# 8        F          KW       KuwaIT  MiddleSchool        5         A     Math
# 10       M          KW       KuwaIT  MiddleSchool        5         A        0
# ..     ...         ...          ...           ...      ...       ...      ...
# 475      F      Jordan       Jordan  MiddleSchool        6         A        0
# 476      F      Jordan       Jordan  MiddleSchool        6         A        0
# 477      F      Jordan       Jordan  MiddleSchool        6         A        0
# 478      F      Jordan       Jordan  MiddleSchool        6         A        0
# 479      F      Jordan       Jordan  MiddleSchool        6         A  History
#
# ...

# %%
file.to_csv('output_II.csv')

# %%
file = pd.read_csv("output_II.csv")
file
# Out:
#      Unnamed: 0 gender NationalITy PlaceofBirth       StageID  GradeID  \
# 0             1      M          KW       KuwaIT    lowerlevel        2
# 1             2      M          KW       KuwaIT    lowerlevel        2
# 2             7      M          KW       KuwaIT  MiddleSchool        5
# 3             8      F          KW       KuwaIT  MiddleSchool        5
# 4            10      M          KW       KuwaIT  MiddleSchool        5
# ..          ...    ...         ...          ...           ...      ...
# 453         475      F      Jordan       Jordan  MiddleSchool        6
# 454         476      F      Jordan       Jordan  MiddleSchool        6
# 455         477      F      Jordan       Jordan  MiddleSchool        6
# 456         478      F      Jordan       Jordan  MiddleSchool        6
# 457         479      F      Jordan       Jordan  MiddleSchool        6
#
#     SectionID    Topic Semester Relation  raisedhands  VisITedResources  \
# ...
